# %%
import os
import numpy as np
import glob
import shutil

import tensorflow as tf

import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
_URL = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

zip_file = tf.keras.utils.get_file(origin=_URL,
                                   fname="flower_photos.tgz",
                                   extract=True)

base_dir = os.path.join(os.path.dirname(zip_file), 'flower_photos')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 2s 0us/step

# %%
classes = ['roses', 'daisy', 'dandelion', 'sunflowers', 'tulips']

# %%
for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  print("{}: {} Images".format(cl, len(images)))
  train, val = images[:round(len(images)*0.8)], images[round(len(images)*0.8):]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))
# Out:
# roses: 641 Images
# daisy: 633 Images
# dandelion: 898 Images
# sunflowers: 699 Images
# tulips: 799 Images

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

# %%
BATCH_SIZE = 100
IMG_SHAPE  = 150 # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %%
image_gen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE,IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(15,15))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()


augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range=45)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
image_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.5)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
image_gen_train = ImageDataGenerator(
      rescale=1./255,
      rotation_range=45,
      width_shift_range=0.15,
      height_shift_range=0.15,
      zoom_range=0.5,
      horizontal_flip=True,
      fill_mode='nearest')


train_data_gen = image_gen_train.flow_from_directory(batch_size=BATCH_SIZE,
                                                     directory=train_dir,
                                                     shuffle=True,
                                                     target_size=(IMG_SHAPE,IMG_SHAPE),
                                                     class_mode='binary')
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=BATCH_SIZE,
                                                 directory=val_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='sparse')
# Out:
# Found 735 images belonging to 5 classes.

# %%
model = tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
      tf.keras.layers.MaxPooling2D(2, 2),

      tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2,2),

      tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2,2),

      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(512, activation='relu'),
      tf.keras.layers.Dense(5)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 256)       147712
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 256)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 17, 17, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 73984)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               37880320
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 38,049,989
# Trainable params: 38,049,989
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 70

history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(BATCH_SIZE))),
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(BATCH_SIZE)))
)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/70
# 30/30 [==============================] - 140s 5s/step - loss: 1.9138 - accuracy: 0.2593 - val_loss: 1.2588 - val_accuracy: 0.4327
# Epoch 2/70
# 30/30 [==============================] - 137s 5s/step - loss: 1.2187 - accuracy: 0.4561 - val_loss: 1.1143 - val_accuracy: 0.5510
# Epoch 3/70
# 30/30 [==============================] - 137s 5s/step - loss: 1.0573 - accuracy: 0.5779 - val_loss: 0.9434 - val_accuracy: 0.6109
# Epoch 4/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.9826 - accuracy: 0.6274 - val_loss: 0.9658 - val_accuracy: 0.6259
# Epoch 5/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.9577 - accuracy: 0.6329 - val_loss: 0.9089 - val_accuracy: 0.6463
# Epoch 6/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.8752 - accuracy: 0.6543 - val_loss: 0.8111 - val_accuracy: 0.6898
# Epoch 7/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.8352 - accuracy: 0.6886 - val_loss: 0.8139 - val_accuracy: 0.6721
# Epoch 8/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.8218 - accuracy: 0.6802 - val_loss: 0.8076 - val_accuracy: 0.7007
# Epoch 9/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.8059 - accuracy: 0.6847 - val_loss: 0.7393 - val_accuracy: 0.7306
# Epoch 10/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.7752 - accuracy: 0.6919 - val_loss: 0.7469 - val_accuracy: 0.7020
# Epoch 11/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.7965 - accuracy: 0.6748 - val_loss: 0.7440 - val_accuracy: 0.7116
# Epoch 12/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.7427 - accuracy: 0.7053 - val_loss: 0.7164 - val_accuracy: 0.7361
# Epoch 13/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.6913 - accuracy: 0.7439 - val_loss: 0.7778 - val_accuracy: 0.6993
# Epoch 14/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.7617 - accuracy: 0.7140 - val_loss: 0.7235 - val_accuracy: 0.7333
# Epoch 15/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.7215 - accuracy: 0.7209 - val_loss: 0.7774 - val_accuracy: 0.7075
# Epoch 16/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.6626 - accuracy: 0.7560 - val_loss: 0.6948 - val_accuracy: 0.7265
# Epoch 17/70
# 30/30 [==============================] - 136s 4s/step - loss: 0.6811 - accuracy: 0.7341 - val_loss: 0.6493 - val_accuracy: 0.7442
# Epoch 18/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.6597 - accuracy: 0.7563 - val_loss: 0.6349 - val_accuracy: 0.7673
# Epoch 19/70
# 30/30 [==============================] - 136s 4s/step - loss: 0.6453 - accuracy: 0.7520 - val_loss: 0.6952 - val_accuracy: 0.7415
# Epoch 20/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.6754 - accuracy: 0.7316 - val_loss: 0.6584 - val_accuracy: 0.7429
# Epoch 21/70
# 30/30 [==============================] - 136s 5s/step - loss: 0.6383 - accuracy: 0.7556 - val_loss: 0.6510 - val_accuracy: 0.7687
# Epoch 22/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.6170 - accuracy: 0.7562 - val_loss: 0.6415 - val_accuracy: 0.7673
# Epoch 23/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.6286 - accuracy: 0.7619 - val_loss: 0.6392 - val_accuracy: 0.7605
# Epoch 24/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5661 - accuracy: 0.7874 - val_loss: 0.6117 - val_accuracy: 0.7633
# Epoch 25/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5978 - accuracy: 0.7753 - val_loss: 0.7041 - val_accuracy: 0.7197
# Epoch 26/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.6214 - accuracy: 0.7652 - val_loss: 0.6422 - val_accuracy: 0.7673
# Epoch 27/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5761 - accuracy: 0.7807 - val_loss: 0.6349 - val_accuracy: 0.7483
# Epoch 28/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5999 - accuracy: 0.7814 - val_loss: 0.6384 - val_accuracy: 0.7537
# Epoch 29/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5643 - accuracy: 0.7789 - val_loss: 0.6003 - val_accuracy: 0.7714
# Epoch 30/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5708 - accuracy: 0.7847 - val_loss: 0.5763 - val_accuracy: 0.8000
# Epoch 31/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5677 - accuracy: 0.7774 - val_loss: 0.6408 - val_accuracy: 0.7673
# Epoch 32/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5217 - accuracy: 0.7998 - val_loss: 0.5832 - val_accuracy: 0.7796
# Epoch 33/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5340 - accuracy: 0.7945 - val_loss: 0.5912 - val_accuracy: 0.7823
# Epoch 34/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5192 - accuracy: 0.8009 - val_loss: 0.5562 - val_accuracy: 0.7973
# Epoch 35/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5188 - accuracy: 0.7917 - val_loss: 0.5724 - val_accuracy: 0.7837
# Epoch 36/70
# 30/30 [==============================] - 134s 4s/step - loss: 0.5087 - accuracy: 0.8045 - val_loss: 0.5471 - val_accuracy: 0.7959
# Epoch 37/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4905 - accuracy: 0.8120 - val_loss: 0.5898 - val_accuracy: 0.7728
# Epoch 38/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4754 - accuracy: 0.8163 - val_loss: 0.5714 - val_accuracy: 0.7796
# Epoch 39/70
# 30/30 [==============================] - 134s 4s/step - loss: 0.4942 - accuracy: 0.8123 - val_loss: 0.5973 - val_accuracy: 0.7823
# Epoch 40/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5133 - accuracy: 0.8072 - val_loss: 0.5771 - val_accuracy: 0.7878
# Epoch 41/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4740 - accuracy: 0.8240 - val_loss: 0.6258 - val_accuracy: 0.7850
# Epoch 42/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4602 - accuracy: 0.8232 - val_loss: 0.6149 - val_accuracy: 0.7673
# Epoch 43/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5068 - accuracy: 0.8094 - val_loss: 0.5661 - val_accuracy: 0.8000
# Epoch 44/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.5000 - accuracy: 0.8055 - val_loss: 0.5766 - val_accuracy: 0.8014
# Epoch 45/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4734 - accuracy: 0.8142 - val_loss: 0.6037 - val_accuracy: 0.7823
# Epoch 46/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4664 - accuracy: 0.8235 - val_loss: 0.5612 - val_accuracy: 0.8041
# Epoch 47/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4522 - accuracy: 0.8278 - val_loss: 0.5668 - val_accuracy: 0.7986
# Epoch 48/70
# 30/30 [==============================] - 134s 4s/step - loss: 0.4691 - accuracy: 0.8207 - val_loss: 0.5668 - val_accuracy: 0.7973
# Epoch 49/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4167 - accuracy: 0.8364 - val_loss: 0.5680 - val_accuracy: 0.8054
# Epoch 50/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4570 - accuracy: 0.8207 - val_loss: 0.5647 - val_accuracy: 0.7946
# Epoch 51/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4125 - accuracy: 0.8381 - val_loss: 0.6090 - val_accuracy: 0.7878
# Epoch 52/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4014 - accuracy: 0.8438 - val_loss: 0.6266 - val_accuracy: 0.7850
# Epoch 53/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4035 - accuracy: 0.8466 - val_loss: 0.5434 - val_accuracy: 0.8122
# Epoch 54/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4151 - accuracy: 0.8435 - val_loss: 0.5792 - val_accuracy: 0.7823
# Epoch 55/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4096 - accuracy: 0.8378 - val_loss: 0.5782 - val_accuracy: 0.8068
# Epoch 56/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4171 - accuracy: 0.8251 - val_loss: 0.5859 - val_accuracy: 0.8136
# Epoch 57/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.4378 - accuracy: 0.8268 - val_loss: 0.5557 - val_accuracy: 0.7878
# Epoch 58/70
# 30/30 [==============================] - 134s 4s/step - loss: 0.3784 - accuracy: 0.8542 - val_loss: 0.5982 - val_accuracy: 0.7959
# Epoch 59/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.3896 - accuracy: 0.8504 - val_loss: 0.5875 - val_accuracy: 0.8000
# Epoch 60/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.3887 - accuracy: 0.8526 - val_loss: 0.6157 - val_accuracy: 0.7959
# Epoch 61/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.3951 - accuracy: 0.8459 - val_loss: 0.6367 - val_accuracy: 0.7946
# Epoch 62/70
# 30/30 [==============================] - 134s 4s/step - loss: 0.4119 - accuracy: 0.8460 - val_loss: 0.5790 - val_accuracy: 0.8259
# Epoch 63/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.3557 - accuracy: 0.8583 - val_loss: 0.6143 - val_accuracy: 0.7986
# Epoch 64/70
# 30/30 [==============================] - 134s 4s/step - loss: 0.3593 - accuracy: 0.8754 - val_loss: 0.5328 - val_accuracy: 0.8177
# Epoch 65/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.3991 - accuracy: 0.8477 - val_loss: 0.6215 - val_accuracy: 0.8014
# Epoch 66/70
# 30/30 [==============================] - 134s 4s/step - loss: 0.3699 - accuracy: 0.8606 - val_loss: 0.5953 - val_accuracy: 0.8177
# Epoch 67/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.3285 - accuracy: 0.8728 - val_loss: 0.5602 - val_accuracy: 0.8259
# Epoch 68/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.3414 - accuracy: 0.8756 - val_loss: 0.5688 - val_accuracy: 0.7973
# Epoch 69/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.3803 - accuracy: 0.8408 - val_loss: 0.6161 - val_accuracy: 0.7823
# Epoch 70/70
# 30/30 [==============================] - 135s 4s/step - loss: 0.3390 - accuracy: 0.8716 - val_loss: 0.5789 - val_accuracy: 0.8163

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

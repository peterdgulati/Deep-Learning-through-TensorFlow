# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
def plot_series(time, series, format="-", start=0, end=None, label=None):
    plt.plot(time[start:end], series[start:end], format, label=label)
    plt.xlabel("Time")
    plt.ylabel("Value")
    if label:
        plt.legend(fontsize=14)
    plt.grid(True)


def trend(time, slope=0):
    return slope * time
  
  
def seasonal_pattern(season_time):
    """Just an arbitrary pattern, you can change it if you wish"""
    return np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

  
def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)
  
  
def white_noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level
  

def seq2seq_window_dataset(series, window_size, batch_size=32,
                           shuffle_buffer=1000):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)
  

def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %%
time = np.arange(4 * 365 + 1)

slope = 0.05
baseline = 10
amplitude = 40
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)

noise_level = 5
noise = white_noise(time, noise_level, seed=42)

series += noise

plt.figure(figsize=(10, 6))
plot_series(time, series)
plt.show()

# %%
split_time = 1000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 30
train_set = seq2seq_window_dataset(x_train, window_size,
                                   batch_size=128)

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=32, kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, 1]),
  tf.keras.layers.LSTM(32, return_sequences=True),
  tf.keras.layers.LSTM(32, return_sequences=True),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 200)
])
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-8, 1e-4, 0, 30])
# Out:
# (1e-08, 0.0001, 0.0, 30.0)

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 30
train_set = seq2seq_window_dataset(x_train, window_size,
                                   batch_size=128)
valid_set = seq2seq_window_dataset(x_valid, window_size,
                                   batch_size=128)

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=32, kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, 1]),
  tf.keras.layers.LSTM(32, return_sequences=True),
  tf.keras.layers.LSTM(32, return_sequences=True),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 200)
])
optimizer = tf.keras.optimizers.SGD(lr=1e-5, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "my_checkpoint.h5", save_best_only=True)
early_stopping = tf.keras.callbacks.EarlyStopping(patience=50)
model.fit(train_set, epochs=500,
          validation_data=valid_set,
          callbacks=[early_stopping, model_checkpoint])

# %%
model = tf.keras.models.load_model("my_checkpoint.h5")

# %%
rnn_forecast = model_forecast(model, series[:,  np.newaxis], window_size)
rnn_forecast = rnn_forecast[split_time - window_size:-1, -1, 0]

# %%
plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)
plot_series(time_valid, rnn_forecast)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecast).numpy()
# Out:
# 5.112706

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 64
train_set = seq2seq_window_dataset(x_train, window_size,
                                   batch_size=128)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.InputLayer(input_shape=[None, 1]))
for dilation_rate in (1, 2, 4, 8, 16, 32):
    model.add(
      tf.keras.layers.Conv1D(filters=32,
                          kernel_size=2,
                          strides=1,
                          dilation_rate=dilation_rate,
                          padding="causal",
                          activation="relu")
    )
model.add(tf.keras.layers.Conv1D(filters=1, kernel_size=1))
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-4 * 10**(epoch / 30))
optimizer = tf.keras.optimizers.Adam(lr=1e-4)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-4, 1e-1, 0, 30])
# Out:
# (0.0001, 0.1, 0.0, 30.0)

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 64
train_set = seq2seq_window_dataset(x_train, window_size,
                                   batch_size=128)
valid_set = seq2seq_window_dataset(x_valid, window_size,
                                   batch_size=128)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.InputLayer(input_shape=[None, 1]))
for dilation_rate in (1, 2, 4, 8, 16, 32):
    model.add(
      tf.keras.layers.Conv1D(filters=32,
                          kernel_size=2,
                          strides=1,
                          dilation_rate=dilation_rate,
                          padding="causal",
                          activation="relu")
    )
model.add(tf.keras.layers.Conv1D(filters=1, kernel_size=1))
optimizer = tf.keras.optimizers.Adam(lr=3e-4)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "my_checkpoint.h5", save_best_only=True)
early_stopping = tf.keras.callbacks.EarlyStopping(patience=50)
history = model.fit(train_set, epochs=500,
                    validation_data=valid_set,
                    callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/500
# 8/8 [==============================] - 2s 86ms/step - loss: 40.2814 - mae: 40.7803 - val_loss: 72.9189 - val_mae: 73.4189
# Epoch 2/500
# 8/8 [==============================] - 0s 22ms/step - loss: 37.8895 - mae: 38.3882 - val_loss: 67.9777 - val_mae: 68.4777
# Epoch 3/500
# 8/8 [==============================] - 0s 24ms/step - loss: 36.0521 - mae: 36.5509 - val_loss: 60.8664 - val_mae: 61.3664
# Epoch 4/500
# 8/8 [==============================] - 0s 22ms/step - loss: 31.9604 - mae: 32.4587 - val_loss: 50.2194 - val_mae: 50.7190
# Epoch 5/500
# 8/8 [==============================] - 0s 23ms/step - loss: 26.0539 - mae: 26.5512 - val_loss: 36.6519 - val_mae: 37.1479
# Epoch 6/500
# 8/8 [==============================] - 0s 23ms/step - loss: 20.5577 - mae: 21.0522 - val_loss: 32.0186 - val_mae: 32.5157
# Epoch 7/500
# 8/8 [==============================] - 0s 24ms/step - loss: 18.8428 - mae: 19.3376 - val_loss: 30.0781 - val_mae: 30.5755
# Epoch 8/500
# 8/8 [==============================] - 0s 23ms/step - loss: 17.8458 - mae: 18.3401 - val_loss: 26.6352 - val_mae: 27.1319
# Epoch 9/500
# 8/8 [==============================] - 0s 25ms/step - loss: 16.0522 - mae: 16.5453 - val_loss: 23.6696 - val_mae: 24.1641
# Epoch 10/500
# 8/8 [==============================] - 0s 24ms/step - loss: 14.2471 - mae: 14.7380 - val_loss: 19.6555 - val_mae: 20.1486
# Epoch 11/500
# 8/8 [==============================] - 0s 24ms/step - loss: 12.3355 - mae: 12.8242 - val_loss: 15.8617 - val_mae: 16.3499
# Epoch 12/500
# 8/8 [==============================] - 0s 23ms/step - loss: 10.3204 - mae: 10.8067 - val_loss: 13.1249 - val_mae: 13.6122
# Epoch 13/500
# 8/8 [==============================] - 0s 25ms/step - loss: 8.9374 - mae: 9.4210 - val_loss: 11.4143 - val_mae: 11.9020
# Epoch 14/500
# 8/8 [==============================] - 0s 24ms/step - loss: 7.8455 - mae: 8.3289 - val_loss: 9.9348 - val_mae: 10.4204
# Epoch 15/500
# 8/8 [==============================] - 0s 23ms/step - loss: 7.0947 - mae: 7.5776 - val_loss: 8.8060 - val_mae: 9.2893
# Epoch 16/500
# 8/8 [==============================] - 0s 26ms/step - loss: 6.6184 - mae: 7.0996 - val_loss: 8.0486 - val_mae: 8.5324
# Epoch 17/500
# 8/8 [==============================] - 0s 24ms/step - loss: 6.2186 - mae: 6.6992 - val_loss: 7.3793 - val_mae: 7.8616
# Epoch 18/500
# 8/8 [==============================] - 0s 24ms/step - loss: 5.7950 - mae: 6.2744 - val_loss: 6.7768 - val_mae: 7.2590
# Epoch 19/500
# 8/8 [==============================] - 0s 24ms/step - loss: 5.5309 - mae: 6.0101 - val_loss: 6.2150 - val_mae: 6.6947
# Epoch 20/500
# 8/8 [==============================] - 0s 22ms/step - loss: 5.2362 - mae: 5.7162 - val_loss: 5.7563 - val_mae: 6.2336
# Epoch 21/500
# 8/8 [==============================] - 0s 23ms/step - loss: 5.0200 - mae: 5.4990 - val_loss: 5.5735 - val_mae: 6.0514
# Epoch 22/500
# 8/8 [==============================] - 0s 22ms/step - loss: 4.9190 - mae: 5.3977 - val_loss: 5.3835 - val_mae: 5.8607
# Epoch 23/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.7974 - mae: 5.2762 - val_loss: 5.2762 - val_mae: 5.7543
# Epoch 24/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.6974 - mae: 5.1764 - val_loss: 5.0938 - val_mae: 5.5701
# Epoch 25/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.6336 - mae: 5.1124 - val_loss: 5.0205 - val_mae: 5.4977
# Epoch 26/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.5620 - mae: 5.0402 - val_loss: 4.8872 - val_mae: 5.3637
# Epoch 27/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.4886 - mae: 4.9665 - val_loss: 4.7814 - val_mae: 5.2573
# Epoch 28/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.4211 - mae: 4.8990 - val_loss: 4.7010 - val_mae: 5.1771
# Epoch 29/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.3652 - mae: 4.8427 - val_loss: 4.6202 - val_mae: 5.0964
# Epoch 30/500
# 8/8 [==============================] - 0s 24ms/step - loss: 4.3106 - mae: 4.7874 - val_loss: 4.5456 - val_mae: 5.0220
# Epoch 31/500
# 8/8 [==============================] - 0s 25ms/step - loss: 4.2579 - mae: 4.7344 - val_loss: 4.5170 - val_mae: 4.9930
# Epoch 32/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.2201 - mae: 4.6953 - val_loss: 4.4620 - val_mae: 4.9378
# Epoch 33/500
# 8/8 [==============================] - 0s 25ms/step - loss: 4.1827 - mae: 4.6577 - val_loss: 4.4320 - val_mae: 4.9080
# Epoch 34/500
# 8/8 [==============================] - 0s 24ms/step - loss: 4.1476 - mae: 4.6227 - val_loss: 4.3950 - val_mae: 4.8710
# Epoch 35/500
# 8/8 [==============================] - 0s 24ms/step - loss: 4.1209 - mae: 4.5957 - val_loss: 4.3867 - val_mae: 4.8628
# Epoch 36/500
# 8/8 [==============================] - 0s 25ms/step - loss: 4.1061 - mae: 4.5808 - val_loss: 4.3925 - val_mae: 4.8689
# Epoch 37/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.0802 - mae: 4.5546 - val_loss: 4.3945 - val_mae: 4.8708
# Epoch 38/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.0633 - mae: 4.5374 - val_loss: 4.3140 - val_mae: 4.7882
# Epoch 39/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.0454 - mae: 4.5193 - val_loss: 4.3518 - val_mae: 4.8274
# Epoch 40/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.0144 - mae: 4.4880 - val_loss: 4.3150 - val_mae: 4.7899
# Epoch 41/500
# 8/8 [==============================] - 0s 23ms/step - loss: 4.0050 - mae: 4.4779 - val_loss: 4.3203 - val_mae: 4.7959
# Epoch 42/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.9881 - mae: 4.4603 - val_loss: 4.2974 - val_mae: 4.7725
# Epoch 43/500
# 8/8 [==============================] - 0s 25ms/step - loss: 3.9807 - mae: 4.4525 - val_loss: 4.3401 - val_mae: 4.8167
# Epoch 44/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.9570 - mae: 4.4287 - val_loss: 4.2988 - val_mae: 4.7739
# Epoch 45/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.9554 - mae: 4.4269 - val_loss: 4.3216 - val_mae: 4.7976
# Epoch 46/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.9432 - mae: 4.4141 - val_loss: 4.2975 - val_mae: 4.7733
# Epoch 47/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.9336 - mae: 4.4048 - val_loss: 4.2978 - val_mae: 4.7734
# Epoch 48/500
# 8/8 [==============================] - 0s 25ms/step - loss: 3.9368 - mae: 4.4084 - val_loss: 4.3242 - val_mae: 4.8006
# Epoch 49/500
# 8/8 [==============================] - 0s 25ms/step - loss: 3.9120 - mae: 4.3835 - val_loss: 4.2537 - val_mae: 4.7279
# Epoch 50/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.9167 - mae: 4.3884 - val_loss: 4.2662 - val_mae: 4.7414
# Epoch 51/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.8943 - mae: 4.3650 - val_loss: 4.3455 - val_mae: 4.8221
# Epoch 52/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.8937 - mae: 4.3648 - val_loss: 4.2451 - val_mae: 4.7194
# Epoch 53/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.8839 - mae: 4.3543 - val_loss: 4.2763 - val_mae: 4.7522
# Epoch 54/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.8667 - mae: 4.3372 - val_loss: 4.2953 - val_mae: 4.7716
# Epoch 55/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.8547 - mae: 4.3243 - val_loss: 4.2391 - val_mae: 4.7133
# Epoch 56/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.8495 - mae: 4.3201 - val_loss: 4.2821 - val_mae: 4.7583
# Epoch 57/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.8518 - mae: 4.3218 - val_loss: 4.2705 - val_mae: 4.7464
# Epoch 58/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.8343 - mae: 4.3035 - val_loss: 4.2965 - val_mae: 4.7731
# Epoch 59/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.8282 - mae: 4.2986 - val_loss: 4.2517 - val_mae: 4.7265
# Epoch 60/500
# 8/8 [==============================] - 0s 25ms/step - loss: 3.8098 - mae: 4.2796 - val_loss: 4.2362 - val_mae: 4.7104
# Epoch 61/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.8095 - mae: 4.2789 - val_loss: 4.2337 - val_mae: 4.7075
# Epoch 62/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7925 - mae: 4.2619 - val_loss: 4.2682 - val_mae: 4.7438
# Epoch 63/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.8047 - mae: 4.2748 - val_loss: 4.2338 - val_mae: 4.7079
# Epoch 64/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7733 - mae: 4.2429 - val_loss: 4.2344 - val_mae: 4.7088
# Epoch 65/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7737 - mae: 4.2436 - val_loss: 4.2444 - val_mae: 4.7191
# Epoch 66/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.7726 - mae: 4.2426 - val_loss: 4.2940 - val_mae: 4.7711
# Epoch 67/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7687 - mae: 4.2375 - val_loss: 4.2547 - val_mae: 4.7299
# Epoch 68/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7494 - mae: 4.2189 - val_loss: 4.2071 - val_mae: 4.6812
# Epoch 69/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.7603 - mae: 4.2294 - val_loss: 4.2974 - val_mae: 4.7747
# Epoch 70/500
# 8/8 [==============================] - 0s 25ms/step - loss: 3.7487 - mae: 4.2178 - val_loss: 4.2006 - val_mae: 4.6744
# Epoch 71/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7377 - mae: 4.2063 - val_loss: 4.2630 - val_mae: 4.7390
# Epoch 72/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7471 - mae: 4.2156 - val_loss: 4.2629 - val_mae: 4.7390
# Epoch 73/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7259 - mae: 4.1949 - val_loss: 4.1920 - val_mae: 4.6660
# Epoch 74/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7253 - mae: 4.1940 - val_loss: 4.2824 - val_mae: 4.7594
# Epoch 75/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.7083 - mae: 4.1766 - val_loss: 4.1978 - val_mae: 4.6718
# Epoch 76/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.7232 - mae: 4.1924 - val_loss: 4.2796 - val_mae: 4.7566
# Epoch 77/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.7153 - mae: 4.1843 - val_loss: 4.2126 - val_mae: 4.6870
# Epoch 78/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.7064 - mae: 4.1753 - val_loss: 4.2271 - val_mae: 4.7020
# Epoch 79/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.7006 - mae: 4.1694 - val_loss: 4.2613 - val_mae: 4.7378
# Epoch 80/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.6972 - mae: 4.1666 - val_loss: 4.2062 - val_mae: 4.6805
# Epoch 81/500
# 8/8 [==============================] - 0s 26ms/step - loss: 3.6791 - mae: 4.1475 - val_loss: 4.2409 - val_mae: 4.7167
# Epoch 82/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.6857 - mae: 4.1543 - val_loss: 4.2211 - val_mae: 4.6964
# Epoch 83/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.6718 - mae: 4.1398 - val_loss: 4.2170 - val_mae: 4.6923
# Epoch 84/500
# 8/8 [==============================] - 0s 26ms/step - loss: 3.6839 - mae: 4.1528 - val_loss: 4.2196 - val_mae: 4.6950
# Epoch 85/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.6748 - mae: 4.1441 - val_loss: 4.2182 - val_mae: 4.6936
# Epoch 86/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.6567 - mae: 4.1247 - val_loss: 4.2120 - val_mae: 4.6873
# Epoch 87/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.6534 - mae: 4.1222 - val_loss: 4.2114 - val_mae: 4.6864
# Epoch 88/500
# 8/8 [==============================] - 0s 25ms/step - loss: 3.6221 - mae: 4.0898 - val_loss: 4.2502 - val_mae: 4.7272
# Epoch 89/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.6255 - mae: 4.0933 - val_loss: 4.2372 - val_mae: 4.7132
# Epoch 90/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.6385 - mae: 4.1062 - val_loss: 4.1851 - val_mae: 4.6595
# Epoch 91/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.6583 - mae: 4.1265 - val_loss: 4.2145 - val_mae: 4.6901
# Epoch 92/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.6321 - mae: 4.0993 - val_loss: 4.2141 - val_mae: 4.6899
# Epoch 93/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.6426 - mae: 4.1097 - val_loss: 4.1872 - val_mae: 4.6623
# Epoch 94/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.5909 - mae: 4.0577 - val_loss: 4.2176 - val_mae: 4.6934
# Epoch 95/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.6255 - mae: 4.0933 - val_loss: 4.1903 - val_mae: 4.6652
# Epoch 96/500
# 8/8 [==============================] - 0s 25ms/step - loss: 3.5968 - mae: 4.0641 - val_loss: 4.2150 - val_mae: 4.6908
# Epoch 97/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.6083 - mae: 4.0760 - val_loss: 4.1908 - val_mae: 4.6660
# Epoch 98/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.6367 - mae: 4.1049 - val_loss: 4.2232 - val_mae: 4.6994
# Epoch 99/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.6015 - mae: 4.0683 - val_loss: 4.2366 - val_mae: 4.7130
# Epoch 100/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.5630 - mae: 4.0291 - val_loss: 4.2082 - val_mae: 4.6843
# Epoch 101/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.5854 - mae: 4.0512 - val_loss: 4.2552 - val_mae: 4.7320
# Epoch 102/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.5610 - mae: 4.0264 - val_loss: 4.2021 - val_mae: 4.6779
# Epoch 103/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.5548 - mae: 4.0200 - val_loss: 4.2147 - val_mae: 4.6911
# Epoch 104/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.5679 - mae: 4.0336 - val_loss: 4.2328 - val_mae: 4.7096
# Epoch 105/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.5481 - mae: 4.0137 - val_loss: 4.1978 - val_mae: 4.6735
# Epoch 106/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.5652 - mae: 4.0300 - val_loss: 4.2676 - val_mae: 4.7442
# Epoch 107/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.5847 - mae: 4.0502 - val_loss: 4.1916 - val_mae: 4.6673
# Epoch 108/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.5545 - mae: 4.0194 - val_loss: 4.2587 - val_mae: 4.7354
# Epoch 109/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.5470 - mae: 4.0120 - val_loss: 4.2059 - val_mae: 4.6820
# Epoch 110/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.5352 - mae: 3.9994 - val_loss: 4.2354 - val_mae: 4.7120
# Epoch 111/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.5434 - mae: 4.0080 - val_loss: 4.2468 - val_mae: 4.7238
# Epoch 112/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.5470 - mae: 4.0121 - val_loss: 4.2006 - val_mae: 4.6765
# Epoch 113/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.5329 - mae: 3.9972 - val_loss: 4.2532 - val_mae: 4.7298
# Epoch 114/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.5242 - mae: 3.9880 - val_loss: 4.2087 - val_mae: 4.6845
# Epoch 115/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.5488 - mae: 4.0140 - val_loss: 4.2020 - val_mae: 4.6785
# Epoch 116/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.5253 - mae: 3.9889 - val_loss: 4.2527 - val_mae: 4.7295
# Epoch 117/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.5185 - mae: 3.9820 - val_loss: 4.1828 - val_mae: 4.6580
# Epoch 118/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.5091 - mae: 3.9715 - val_loss: 4.2984 - val_mae: 4.7755
# Epoch 119/500
# 8/8 [==============================] - 0s 21ms/step - loss: 3.4954 - mae: 3.9582 - val_loss: 4.1943 - val_mae: 4.6702
# Epoch 120/500
# 8/8 [==============================] - 0s 25ms/step - loss: 3.5221 - mae: 3.9858 - val_loss: 4.2171 - val_mae: 4.6936
# Epoch 121/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.5211 - mae: 3.9846 - val_loss: 4.2636 - val_mae: 4.7398
# Epoch 122/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.5358 - mae: 4.0002 - val_loss: 4.2015 - val_mae: 4.6777
# Epoch 123/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4900 - mae: 3.9523 - val_loss: 4.2282 - val_mae: 4.7040
# Epoch 124/500
# 8/8 [==============================] - 0s 21ms/step - loss: 3.5121 - mae: 3.9759 - val_loss: 4.2165 - val_mae: 4.6926
# Epoch 125/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4767 - mae: 3.9397 - val_loss: 4.2033 - val_mae: 4.6794
# Epoch 126/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.4808 - mae: 3.9439 - val_loss: 4.2118 - val_mae: 4.6880
# Epoch 127/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.5131 - mae: 3.9765 - val_loss: 4.2798 - val_mae: 4.7561
# Epoch 128/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4763 - mae: 3.9388 - val_loss: 4.2088 - val_mae: 4.6847
# Epoch 129/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.4875 - mae: 3.9494 - val_loss: 4.1981 - val_mae: 4.6738
# Epoch 130/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4771 - mae: 3.9388 - val_loss: 4.2682 - val_mae: 4.7445
# Epoch 131/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4775 - mae: 3.9391 - val_loss: 4.2617 - val_mae: 4.7374
# Epoch 132/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.4635 - mae: 3.9253 - val_loss: 4.2111 - val_mae: 4.6869
# Epoch 133/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4823 - mae: 3.9449 - val_loss: 4.2118 - val_mae: 4.6875
# Epoch 134/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4755 - mae: 3.9376 - val_loss: 4.2309 - val_mae: 4.7065
# Epoch 135/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.4801 - mae: 3.9417 - val_loss: 4.2689 - val_mae: 4.7450
# Epoch 136/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4429 - mae: 3.9031 - val_loss: 4.2333 - val_mae: 4.7089
# Epoch 137/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4397 - mae: 3.8995 - val_loss: 4.2489 - val_mae: 4.7252
# Epoch 138/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.4499 - mae: 3.9108 - val_loss: 4.2817 - val_mae: 4.7580
# Epoch 139/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4354 - mae: 3.8953 - val_loss: 4.2057 - val_mae: 4.6815
# Epoch 140/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.4297 - mae: 3.8891 - val_loss: 4.2232 - val_mae: 4.6986
# Epoch 141/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4435 - mae: 3.9034 - val_loss: 4.2832 - val_mae: 4.7592
# Epoch 142/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.4277 - mae: 3.8877 - val_loss: 4.2345 - val_mae: 4.7101
# Epoch 143/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4467 - mae: 3.9069 - val_loss: 4.2047 - val_mae: 4.6799
# Epoch 144/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4381 - mae: 3.8975 - val_loss: 4.2213 - val_mae: 4.6964
# Epoch 145/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4276 - mae: 3.8866 - val_loss: 4.2412 - val_mae: 4.7168
# Epoch 146/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.4138 - mae: 3.8719 - val_loss: 4.2163 - val_mae: 4.6913
# Epoch 147/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.4241 - mae: 3.8832 - val_loss: 4.2604 - val_mae: 4.7360
# Epoch 148/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.4041 - mae: 3.8620 - val_loss: 4.2668 - val_mae: 4.7428
# Epoch 149/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.3973 - mae: 3.8548 - val_loss: 4.2558 - val_mae: 4.7310
# Epoch 150/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.4097 - mae: 3.8677 - val_loss: 4.2507 - val_mae: 4.7260
# Epoch 151/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.3925 - mae: 3.8499 - val_loss: 4.2172 - val_mae: 4.6922
# Epoch 152/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.3940 - mae: 3.8507 - val_loss: 4.2099 - val_mae: 4.6849
# Epoch 153/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.4203 - mae: 3.8788 - val_loss: 4.2671 - val_mae: 4.7427
# Epoch 154/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.3882 - mae: 3.8455 - val_loss: 4.2637 - val_mae: 4.7389
# Epoch 155/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.3844 - mae: 3.8418 - val_loss: 4.2721 - val_mae: 4.7479
# Epoch 156/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.3764 - mae: 3.8331 - val_loss: 4.2438 - val_mae: 4.7191
# Epoch 157/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.4096 - mae: 3.8667 - val_loss: 4.2092 - val_mae: 4.6842
# Epoch 158/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.3920 - mae: 3.8484 - val_loss: 4.2091 - val_mae: 4.6840
# Epoch 159/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.3883 - mae: 3.8450 - val_loss: 4.2271 - val_mae: 4.7023
# Epoch 160/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.3491 - mae: 3.8052 - val_loss: 4.2393 - val_mae: 4.7145
# Epoch 161/500
# 8/8 [==============================] - 0s 24ms/step - loss: 3.3809 - mae: 3.8375 - val_loss: 4.2582 - val_mae: 4.7333
# Epoch 162/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.3752 - mae: 3.8319 - val_loss: 4.3322 - val_mae: 4.8092
# Epoch 163/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.3708 - mae: 3.8276 - val_loss: 4.3817 - val_mae: 4.8587
# Epoch 164/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.3558 - mae: 3.8119 - val_loss: 4.3075 - val_mae: 4.7838
# Epoch 165/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.3754 - mae: 3.8319 - val_loss: 4.2917 - val_mae: 4.7677
# Epoch 166/500
# 8/8 [==============================] - 0s 23ms/step - loss: 3.3572 - mae: 3.8133 - val_loss: 4.3142 - val_mae: 4.7909
# Epoch 167/500
# 8/8 [==============================] - 0s 22ms/step - loss: 3.3672 - mae: 3.8228 - val_loss: 4.2618 - val_mae: 4.7376

# %%
model = tf.keras.models.load_model("my_checkpoint.h5")

# %%
cnn_forecast = model_forecast(model, series[..., np.newaxis], window_size)
cnn_forecast = cnn_forecast[split_time - window_size:-1, -1, 0]

# %%
plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)
plot_series(time_valid, cnn_forecast)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, cnn_forecast).numpy()
# Out:
# 4.529195
